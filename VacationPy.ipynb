# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install hvplot
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting hvplot
#   Downloading hvplot-0.8.4-py2.py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 3.9 MB/s            ��                     | 1.1 MB 3.9 MB/s eta 0:00:01
# Collecting bokeh>=1.0.0
#   Downloading bokeh-3.2.0-py3-none-any.whl (7.8 MB)
#      |████████████████████████████████| 7.8 MB 13.2 MB/s            ��███████████████████████████▊   | 7.0 MB 13.2 MB/s eta 0:00:01
# Collecting panel>=0.11.0
#   Downloading panel-1.2.0-py2.py3-none-any.whl (20.0 MB)
#      |████████████████████████████████| 20.0 MB 28.6 MB/s
# Collecting param>=1.9.0
#   Downloading param-1.13.0-py2.py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 6.4 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from hvplot) (21.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/site-packages (from hvplot) (1.3.5)
# Collecting holoviews>=1.11.0
#   Downloading holoviews-1.16.2-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 16.5 MB/s            ��█████████████▋     | 3.6 MB 16.5 MB/s eta 0:00:01
# Collecting colorcet>=2
#   Downloading colorcet-3.0.1-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 18.2 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/site-packages (from hvplot) (1.22.1)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.9/site-packages (from bokeh>=1.0.0->hvplot) (6.2)
# Collecting Jinja2>=2.9
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 16.5 MB/s
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.9/site-packages (from bokeh>=1.0.0->hvplot) (9.1.0)
# Collecting xyzservices>=2021.09.1
#   Downloading xyzservices-2023.7.0-py3-none-any.whl (56 kB)
#      |████████████████████████████████| 56 kB 9.6 MB/s
# Collecting PyYAML>=3.10
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      |████████████████████████████████| 197 kB 40.2 MB/s
# Collecting contourpy>=1
#   Downloading contourpy-1.1.0-cp39-cp39-macosx_10_9_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 20.9 MB/s
# Collecting pyct>=0.4.4
#   Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.3.2-py2.py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 9.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging->hvplot) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/site-packages (from pandas->hvplot) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/site-packages (from pandas->hvplot) (2.8.2)
# Collecting markdown
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 3.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (from panel>=0.11.0->hvplot) (2.31.0)
# Collecting bleach
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 39.3 MB/s
# Collecting linkify-it-py
#   Downloading linkify_it_py-2.0.2-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.4.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 5.8 MB/s
# Collecting tqdm>=4.48.0
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 11.2 MB/s
# Collecting markdown-it-py
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 7.3 MB/s
# Collecting typing-extensions
#   Downloading typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas->hvplot) (1.16.0)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.2-py3-none-any.whl (6.2 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests->panel>=0.11.0->hvplot) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests->panel>=0.11.0->hvplot) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests->panel>=0.11.0->hvplot) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests->panel>=0.11.0->hvplot) (2.0.3)
# Collecting zipp>=0.5
#   Downloading zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Installing collected packages: zipp, mdurl, MarkupSafe, xyzservices, webencodings, uc-micro-py, PyYAML, param, markdown-it-py, Jinja2, importlib-metadata, contourpy, typing-extensions, tqdm, pyviz-comms, pyct, mdit-py-plugins, markdown, linkify-it-py, bokeh, bleach, panel, colorcet, holoviews, hvplot
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3 PyYAML-6.0.1 bleach-6.0.0 bokeh-3.2.0 colorcet-3.0.1 contourpy-1.1.0 holoviews-1.16.2 hvplot-0.8.4 importlib-metadata-6.8.0 linkify-it-py-2.0.2 markdown-3.4.3 markdown-it-py-3.0.0 mdit-py-plugins-0.4.0 mdurl-0.1.2 panel-1.2.0 param-1.13.0 pyct-0.5.0 pyviz-comms-2.3.2 tqdm-4.65.0 typing-extensions-4.7.1 uc-micro-py-1.0.2 webencodings-0.5.1 xyzservices-2023.7.0 zipp-3.16.2
# WARNING: You are using pip version 21.3.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/opt/python@3.9/bin/python3.9 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     isafjordur  66.0755  -23.1240    279.46        93         100
# 1        1        gazojak  41.1875   61.4036    305.82        18           0
# 2        2  port mathurin -19.6833   63.4167    297.19        81          86
# 3        3      jamestown  42.0970  -79.2353    289.83        96           0
# 4        4      adamstown -25.0660 -130.1015    294.34        78          12
#
#    Wind Speed Country        Date
# 0        7.86      IS  1689310428
# 1        4.47      TM  1689310428
# 2        7.35      MU  1689310428
# 3        0.45      US  1689310274
# 4        3.06      PN  1689310429

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
import geoviews as gv
import geoviews.feature as gf

from geoviews import opts
from cartopy import crs

gv.extension('bokeh', 'matplotlib')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %%
# %%capture --no-display

# Configure the map plot

humidity = city_data_df["Humidity"]

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75
)

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# Temperature stored in Kelvin, so 27 Kelvin is 300 celsius and 294.15 kelvin is 21 celsius

city_data_df = city_data_df.loc[(city_data_df["Max Temp"] < 300) & (city_data_df["Max Temp"] > 294.15)]
city_data_df = city_data_df.loc[(city_data_df["Wind Speed"] < 4.5)]
city_data_df = city_data_df.loc[(city_data_df["Cloudiness"] == 0)]
city_data_df = city_data_df.dropna()
city_data_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 41        41  sao miguel do araguaia -13.2750  -50.1628    296.73        35
# 58        58            spring creek  40.7266 -115.5859    296.98        27
# 110      110                florence  43.7667   11.2500    296.65        91
# 112      112           alice springs -23.7000  133.8833    297.90        23
# 135      135              brigantine  39.4101  -74.3646    299.84        91
# 151      151               brookings  44.3114  -96.7984    295.47        83
# 180      180                cabedelo  -6.9811  -34.8339    296.52        78
# 185      185                   adler  43.4300   39.9200    294.24        64
# 198      198               karpenisi  38.9167   21.7833    298.33        51
# 231      231                   hizan  38.2257   42.4278    297.72        38
# 248      248                 bojnurd  37.4747   57.3290    297.12        50
# 250      250                  touros  -5.1989  -35.4608    296.88        81
# 310      310             mcminnville  45.2101 -123.1987    299.19        50
# 312      312              carloforte  39.1450    8.3058    297.63        73
# 328      328                portland  45.5234 -122.6762    299.38        51
# 352      352                severnyy  50.6770   36.5532    294.17        68
# 386      386                hamilton  39.1834  -84.5333    297.27        87
# 392      392                    ghat  24.9647   10.1728    299.89        17
# 394      394                uliastay  47.7417   96.8444    295.33        35
# 412      412                  illizi  26.4833    8.4667    297.04        16
# 426      426              vila velha -20.3297  -40.2925    295.12        91
# 446      446                  mateur  37.0405    9.6656    297.94        71
# 448      448               anapskaya  44.8900   37.3800    296.28        83
# 489      489                  licata  37.1071   13.9461    299.39        58
# 493      493                buctzotz  21.2000  -88.7833    299.68        83
# 550      550              dodge city  37.7528 -100.0171    299.39        82
#
#      Cloudiness  Wind Speed Country        Date
# 41            0        1.48      BR  1689310437
# 58            0        0.73      US  1689310441
# 110           0        0.51      IT  1689310454
# 112           0        2.06      AU  1689310455
# 135           0        3.60      US  1689310463
# 151           0        2.57      US  1689310359
# 180           0        2.89      BR  1689310474
# 185           0        4.00      RU  1689310475
# 198           0        0.18      GR  1689310479
# 231           0        3.41      TR  1689310487
# 248           0        3.09      IR  1689310492
# 250           0        4.48      BR  1689310492
# 310           0        3.60      US  1689310219
# 312           0        4.06      IT  1689310507
# 328           0        1.34      US  1689310341
# 352           0        2.00      RU  1689310520
# 386           0        0.00      US  1689310254
# 392           0        2.21      LY  1689310529
# 394           0        1.54      MN  1689310530
# 412           0        3.21      DZ  1689310534
# 426           0        2.06      BR  1689310538
# 446           0        0.30      TN  1689310283
# 448           0        4.00      RU  1689310544
# 489           0        2.16      IT  1689310553
# 493           0        2.65      MX  1689310554
# 550           0        3.60      US  1689310569

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity

city = city_data_df["City"]
country = city_data_df["Country"]
lat = city_data_df["Lat"]
lng = city_data_df["Lng"]
humidity = city_data_df["Humidity"]

hotel_df = city_data_df[{"City": city,
                        "Country": country,
                        "Lat": lat,
                        "Lng": lng,
                        "Humidity": humidity}]

hotel_df["Hotel Name"] = ""

hotel_df
# Out:
# /var/folders/g4/1hmd5hyj7nb5zqfwcw5b74jw0000gn/T/ipykernel_20929/584938163.py:7: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   hotel_df = city_data_df[{"City": city,
# /var/folders/g4/1hmd5hyj7nb5zqfwcw5b74jw0000gn/T/ipykernel_20929/584938163.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                        City Country      Lat       Lng  Humidity Hotel Name
# 41   sao miguel do araguaia      BR -13.2750  -50.1628        35
# 58             spring creek      US  40.7266 -115.5859        27
# 110                florence      IT  43.7667   11.2500        91
# 112           alice springs      AU -23.7000  133.8833        23
# 135              brigantine      US  39.4101  -74.3646        91
# 151               brookings      US  44.3114  -96.7984        83
# 180                cabedelo      BR  -6.9811  -34.8339        78
# 185                   adler      RU  43.4300   39.9200        64
# 198               karpenisi      GR  38.9167   21.7833        51
# 231                   hizan      TR  38.2257   42.4278        38
# 248                 bojnurd      IR  37.4747   57.3290        50
# 250                  touros      BR  -5.1989  -35.4608        81
# 310             mcminnville      US  45.2101 -123.1987        50
# 312              carloforte      IT  39.1450    8.3058        73
# 328                portland      US  45.5234 -122.6762        51
# 352                severnyy      RU  50.6770   36.5532        68
# 386                hamilton      US  39.1834  -84.5333        87
# 392                    ghat      LY  24.9647   10.1728        17
# 394                uliastay      MN  47.7417   96.8444        35
# 412                  illizi      DZ  26.4833    8.4667        16
# 426              vila velha      BR -20.3297  -40.2925        91
# 446                  mateur      TN  37.0405    9.6656        71
# 448               anapskaya      RU  44.8900   37.3800        83
# 489                  licata      IT  37.1071   13.9461        58
# 493                buctzotz      MX  21.2000  -88.7833        83
# 550              dodge city      US  37.7528 -100.0171        82

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
"categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# sao miguel do araguaia - nearest hotel: Hotel São Miguel
# spring creek - nearest hotel: No hotel found
# florence - nearest hotel: Old bridge Apartment
# alice springs - nearest hotel: Aurora Alice Springs
# brigantine - nearest hotel: The Sea Gull
# brookings - nearest hotel: Quality Inn
# cabedelo - nearest hotel: No hotel found
# adler - nearest hotel: Shine
# karpenisi - nearest hotel: avaris
# hizan - nearest hotel: Hizan Öğretmen Evi
# bojnurd - nearest hotel: مرکز آموزشی رفاهی فرهنگیان بجنورد
# touros - nearest hotel: Pousada Atlântico
# mcminnville - nearest hotel: Hotel Oregon
# carloforte - nearest hotel: Hotel Riviera
# portland - nearest hotel: the Hoxton
# severnyy - nearest hotel: Космос
# hamilton - nearest hotel: North Vista Manor
# ghat - nearest hotel: فندق تاسيلي
# uliastay - nearest hotel: Болоржин зочид буудал
# illizi - nearest hotel: بوناقة
# vila velha - nearest hotel: Hotel Prainha
# mateur - nearest hotel: No hotel found
# anapskaya - nearest hotel: Red Hotel
# licata - nearest hotel: Villa Giuliana Relais
# buctzotz - nearest hotel: Hotel Tapia
# dodge city - nearest hotel: Holiday Inn Express & Suites Dodge City, an IHG Hotel
#                        City Country      Lat       Lng  Humidity  \
# 41   sao miguel do araguaia      BR -13.2750  -50.1628        35
# 58             spring creek      US  40.7266 -115.5859        27
# 110                florence      IT  43.7667   11.2500        91
# 112           alice springs      AU -23.7000  133.8833        23
# 135              brigantine      US  39.4101  -74.3646        91
# 151               brookings      US  44.3114  -96.7984        83
# 180                cabedelo      BR  -6.9811  -34.8339        78
# 185                   adler      RU  43.4300   39.9200        64
# 198               karpenisi      GR  38.9167   21.7833        51
# 231                   hizan      TR  38.2257   42.4278        38
# 248                 bojnurd      IR  37.4747   57.3290        50
# 250                  touros      BR  -5.1989  -35.4608        81
# 310             mcminnville      US  45.2101 -123.1987        50
# 312              carloforte      IT  39.1450    8.3058        73
# 328                portland      US  45.5234 -122.6762        51
# 352                severnyy      RU  50.6770   36.5532        68
# 386                hamilton      US  39.1834  -84.5333        87
# 392                    ghat      LY  24.9647   10.1728        17
# 394                uliastay      MN  47.7417   96.8444        35
# 412                  illizi      DZ  26.4833    8.4667        16
# 426              vila velha      BR -20.3297  -40.2925        91
# 446                  mateur      TN  37.0405    9.6656        71
# 448               anapskaya      RU  44.8900   37.3800        83
# 489                  licata      IT  37.1071   13.9461        58
# 493                buctzotz      MX  21.2000  -88.7833        83
# 550              dodge city      US  37.7528 -100.0171        82
#
#                                             Hotel Name
# 41                                    Hotel São Miguel
# 58                                      No hotel found
# 110                               Old bridge Apartment
# 112                               Aurora Alice Springs
# 135                                       The Sea Gull
# 151                                        Quality Inn
# 180                                     No hotel found
# 185                                              Shine
# 198                                             avaris
# 231                                 Hizan Öğretmen Evi
# 248                  مرکز آموزشی رفاهی فرهنگیان بجنورد
# 250                                  Pousada Atlântico
# 310                                       Hotel Oregon
# 312                                      Hotel Riviera
# 328                                         the Hoxton
# 352                                             Космос
# 386                                  North Vista Manor
# 392                                        فندق تاسيلي
# 394                              Болоржин зочид буудал
# 412                                             بوناقة
# 426                                      Hotel Prainha
# 446                                     No hotel found
# 448                                          Red Hotel
# 489                              Villa Giuliana Relais
# 493                                        Hotel Tapia
# 550  Holiday Inn Express & Suites Dodge City, an IH...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
map_plot2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
